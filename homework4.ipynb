# %% [markdown]
# ## **[문제 1] 수업 자료에서 제시하고 있는 다음 코드들을 Backend AI로 옮겨 실행하고 각 결과를 Backend AI 내에 잘 정리하여 제시하기**

# %% [markdown]
# ### **_01_code/_15_lstm_and_its_application/g_crypto_currency_regression_train_lstm.py**

# %% [markdown]
# [실행 결과]
# 1. 최종 Epoch: 1680
# 학습은 Early Stopping 기준에 따라 30회 연속 검증 손실(V_loss)이 감소하지 않아 조기 종료됨.
#
# 2. 최종 성능(최종 저장 모델):
# Training Loss(T_loss): 0.02531
# Validation Loss(V_loss): 0.22655
#
# 3. Early Stopping 기록:
# Epoch 1680에서 Early Stopping Counter가 최대값(30)에 도달하여 학습이 종료됨.
# Early Stopping 발생 전 가장 낮은 검증 손실:
# Epoch 780: Validation Loss가 0.22655로 가장 낮았으며, 이 시점에서 모델이 저장됨.
#
# 4. 모델 저장:
# 최근 Validation Loss 개선 기록:
# Epoch 720: 0.23449 → 0.22807
# Epoch 750: 0.22807 → 0.22770
# Epoch 780: 0.22770 → 0.22655
#
# 5. 학습 시간:
# 총 학습 시간: 00:01:37
# 학습 속도의 효율성을 위해 GPU 환경에서 안정적인 학습이 이루어짐.

# %% [markdown]
# ### **_01_code/_15_lstm_and_its_application/h_crypto_currency_regression_test_lstm.py**

# %% [markdown]
# [실행 결과]
# 1. 테스트 결과:
# 예측값(Mean Prediction): 929.90
# 실제값(Mean Target): 1,186.26
# 평균 절대 오차(Mean Absolute Error): 256.36
#
# 2. 결론:
# 모델의 평균 절대 오차(Mean Absolute Error)는 약 256.36으로, 예측값과 실제값 사이에 다소 큰 차이가 존재함.

# %% [markdown]
# [출력 그래프]

# %% [markdown]
# ![image.png](attachment:602a664a-63b1-4015-a8a0-3a54ea089bbd.png)

# %% [markdown]
# ### **_01_code/_15_lstm_and_its_application/i_crypto_currency_classification_train_lstm.py**

# %% [markdown]
# [실행 결과]
# 1. 최종 Epoch: 1290
# 학습은 Early Stopping 기준에 따라 30회 연속 검증 손실(V_loss)이 감소하지 않아 조기 종료됨.
#
# 2. 최종 성능(최종 저장 모델):
# Train Loss(T_loss): 0.69022
# Train Accuracy(T_accuracy): 53.33%
# Validation Loss(V_loss): 0.69205
# Validation Accuracy(V_accuracy): 56.00%
#
# 3. Early Stopping 기록:
# Epoch 1290에서 Early Stopping Counter가 최대값(30)에 도달하여 학습이 종료됨.
# Early Stopping 발생 전 가장 낮은 검증 손실:
# Epoch 390: Validation Loss가 0.69205로 가장 낮았으며, 이 시점에서 모델이 저장됨.
#
# 4. 모델 저장:
# 최근 Validation Loss 개선 기록:
# Epoch 390: 0.69227 → 0.69205(Validation Accuracy: 56.00%)
#
# 5. 학습 시간:
# 총 학습 시간: 00:01:55
# 학습 속도의 효율성을 위해 GPU 환경에서 안정적인 학습이 이루어짐.

# %% [markdown]
# ### **_01_code/_15_lstm_and_its_application/j_crypto_currency_classification_test_lstm.py**

# %% [markdown]
# [실행 결과]
# 1. 테스트 결과:
# Test Accuracy: 50.00%
#
# 2. 결론:
# 모델의 테스트 정확도는 50.00%로, 데이터가 2개의 클래스(0과 1)로 구성되어 있는 것을 고려하면 무작위 추측 수준이라고 볼 수 있음.

# %% [markdown]
# ## **[문제 2] 적절한 새로운 모델 구성 및 하이퍼파라미터 찾기**

# %% [markdown]
# ### **[모델 구성 및 하이퍼파라미터 값]**

# %% [markdown]
# #### **[Regression]**

# %% [markdown]
# ![image.png](attachment:4b34665b-2d34-41b9-9a2d-4c73e999c305.png)

# %% [markdown]
# · 위 이미지를 통해 알 수 있듯이 총 14번의 시도를 하였고, Regression 문제 학습 시 가장 학습이 잘 된 '모델 구성 및 하이퍼파라미터 값(변경 시도 값)'은 다음과 같다.
# [LSTM layer 개수 : 3]
# [Linear layer 개수 : 1]
# [weight decay : 1e-3]
# [dropout rate : 0.0]

# %% [markdown]
# #### **[Classification]**

# %% [markdown]
# ![image.png](attachment:202b1e87-f7c8-4784-aa1a-5bac14ffa6af.png)

# %% [markdown]
# · 위 이미지를 통해 알 수 있듯이 총 14번의 시도를 하였고, Classification 문제 학습 시 가장 학습이 잘 된 '모델 구성 및 하이퍼파라미터 값(변경 시도 값)'은 다음과 같다.
# [LSTM layer 개수 : 3]
# [Linear layer 개수 : 1]
# [weight decay : 0.0]
# [dropout rate : 0.3]

# %% [markdown]
# ### **[출력 결과]**

# %% [markdown]
# #### **[Regression]**

# %% [markdown]
# ![image.png](attachment:db396e95-7138-4d58-b518-221114e85760.png)

# %% [markdown]
# ![image.png](attachment:5a59d738-a378-47fa-b752-fd75bca7a968.png)

# %% [markdown]
# #### **[Classification]**

# %% [markdown]
# ![image.png](attachment:4dddcc7c-3785-4e2b-9b56-5c29e9b1beb4.png)

# %% [markdown]
# ## **[문제 3] 데이터 Feature 추가 후 성능 변화 확인하기**

# %% [markdown]
# ### **[Regression]**

# %% [markdown]
# #### **[학습 성능 비교]**

# %% [markdown]
# Feature 추가 전:
#
# wandb:                        Epoch 1650
# wandb:                Training loss 0.60649
# wandb: Training speed (epochs/sec.) 10.85526
# wandb:              Validation loss 0.58924
#
# Feature 추가 후:
#
# wandb:                        Epoch 3690
# wandb:                Training loss 0.00025
# wandb: Training speed (epochs/sec.) 14.97759
# wandb:              Validation loss 0.0067
#
# - 이 결과를 보니, 이 Feature가 비트코인 데이터 예측에 지대한 긍정적인 영향을 미친다는 것을 알게 되었다.

# %% [markdown]
# #### **[테스트 성능 비교]**

# %% [markdown]
# [Feature 추가 후]

# %% [markdown]
# ![image.png](attachment:19cf91d1-cccf-49a9-8ea9-dcf218fbb668.png)

# %% [markdown]
# ![image.png](attachment:788ae7be-91cd-4e0b-b1ad-be9c9244d269.png)

# %% [markdown]
# ### **[Classification]**

# %% [markdown]
# #### **[학습 성능 비교]**

# %% [markdown]
# #### **[테스트 성능 비교]**

# %% [markdown]
# ## **[숙제 후기]**

# %% [markdown]
# regression 문제의 성능에 비해 classification 문제의 성능이 아쉬운 결과인 것 같아서 약간은 불만족스러웠지만 LSTM의 위력을 본 것 같아서 이 부분은 만족스러웠다.
